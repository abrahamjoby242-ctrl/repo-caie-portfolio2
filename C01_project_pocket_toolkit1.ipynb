# %% [markdown]
# <a href="https://colab.research.google.com/github/abrahamjoby242-ctrl/repo-caie-portfolio2/blob/main/C01_project_pocket_toolkit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ready")
# Out:
# ready
